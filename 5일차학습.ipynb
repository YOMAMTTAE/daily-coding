# %% [markdown]
# <a href="https://colab.research.google.com/github/YOMAMTTAE/daily-coding/blob/main/5%EC%9D%BC%EC%B0%A8%ED%95%99%EC%8A%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def 정산기(이름, 시간):
  시급 = 20000
  식대 = 10000
  if 시간 > 8:
    급여 = (8*시급)+((시간-8)*시급*1.5)
  else:
    급여 = 시간*시급

  최종금액 = 급여 + 시급
  return[이름, 시간, 최종금액]

오늘의_장부 = []

오늘의_장부.append(정산기("강민수", 8))
오늘의_장부.append(정산기("이진철", 10))
오늘의_장부.append(정산기("박기태", 6))

print("--- 오늘의 최종 장부 데이터 ---")
for 기록 in 오늘의_장부:
  print(f"성함: {기록[0]}, 시간: {기록[1]}시간, 정산액: {기록[2]}원")
# Out:
# --- 오늘의 최종 장부 데이터 ---
# 성함: 강민수, 시간: 8시간, 정산액: 180000원
# 성함: 이진철, 시간: 10시간, 정산액: 240000.0원
# 성함: 박기태, 시간: 6시간, 정산액: 140000원
